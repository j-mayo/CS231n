# %% [markdown]
# <a href="https://colab.research.google.com/github/j-mayo/CS231n/blob/main/features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'CS231n/assignment1/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/CS231n/assignment1/cs231n/datasets
# /content/drive/My Drive/CS231n/assignment1

# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

# learning_rates = [1e-9, 5e-9, 1e-8, 5e-8, 1e-7, 5e-7, 1e-6, 5e-6, 1e-5]
# regularization_strengths = [1e2, 5e2, 1e3, 5e3, 5e4, 5e5, 5e6]

learning_rates = np.arange(1e-6, 1e-5, 2.5e-6)
regularization_strengths = np.arange(1e4, 5e5, 2.5e3)

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for lr in learning_rates:
    for rs in regularization_strengths:
        svm = LinearSVM()
        svm.train(X_train_feats, y_train, learning_rate=lr, reg=rs)

        y_train_pred = svm.predict(X_train_feats)
        y_val_pred = svm.predict(X_val_feats)
        train_accuracy = np.mean(y_train_pred == y_train)
        val_accuracy = np.mean(y_val_pred == y_val)

        if val_accuracy > best_val:
            best_val = val_accuracy
            best_svm = svm
        
        results[(lr, rs)] = (train_accuracy, val_accuracy)

# lr 1.000000e-06 reg 7.000000e+04 is the best model(val_accuracy 0.441)

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved: %f' % best_val)
# Out:
# lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.143306 val accuracy: 0.155000
# lr 1.000000e-06 reg 1.250000e+04 train accuracy: 0.148490 val accuracy: 0.159000
# lr 1.000000e-06 reg 1.500000e+04 train accuracy: 0.193571 val accuracy: 0.223000
# lr 1.000000e-06 reg 1.750000e+04 train accuracy: 0.201980 val accuracy: 0.239000
# lr 1.000000e-06 reg 2.000000e+04 train accuracy: 0.234571 val accuracy: 0.225000
# lr 1.000000e-06 reg 2.250000e+04 train accuracy: 0.297224 val accuracy: 0.318000
# lr 1.000000e-06 reg 2.500000e+04 train accuracy: 0.339531 val accuracy: 0.336000
# lr 1.000000e-06 reg 2.750000e+04 train accuracy: 0.370633 val accuracy: 0.377000
# lr 1.000000e-06 reg 3.000000e+04 train accuracy: 0.390265 val accuracy: 0.393000
# lr 1.000000e-06 reg 3.250000e+04 train accuracy: 0.397694 val accuracy: 0.402000
# lr 1.000000e-06 reg 3.500000e+04 train accuracy: 0.411735 val accuracy: 0.418000
# lr 1.000000e-06 reg 3.750000e+04 train accuracy: 0.412122 val accuracy: 0.412000
# lr 1.000000e-06 reg 4.000000e+04 train accuracy: 0.403551 val accuracy: 0.388000
# lr 1.000000e-06 reg 4.250000e+04 train accuracy: 0.408184 val accuracy: 0.410000
# lr 1.000000e-06 reg 4.500000e+04 train accuracy: 0.417592 val accuracy: 0.415000
# lr 1.000000e-06 reg 4.750000e+04 train accuracy: 0.398102 val accuracy: 0.389000
# lr 1.000000e-06 reg 5.000000e+04 train accuracy: 0.400204 val accuracy: 0.393000
# lr 1.000000e-06 reg 5.250000e+04 train accuracy: 0.399469 val accuracy: 0.389000
# lr 1.000000e-06 reg 2.200000e+05 train accuracy: 0.373408 val accuracy: 0.372000
# lr 1.000000e-06 reg 2.225000e+05 train accuracy: 0.371469 val accuracy: 0.355000
# lr 1.000000e-06 reg 2.250000e+05 train accuracy: 0.350551 val accuracy: 0.341000
# lr 1.000000e-06 reg 2.275000e+05 train accuracy: 0.362673 val accuracy: 0.353000
# lr 1.000000e-06 reg 2.300000e+05 train accuracy: 0.360571 val accuracy: 0.349000
# lr 1.000000e-06 reg 2.325000e+05 train accuracy: 0.369143 val accuracy: 0.383000
# lr 1.000000e-06 reg 2.350000e+05 train accuracy: 0.364571 val accuracy: 0.348000
# lr 1.000000e-06 reg 2.375000e+05 train accuracy: 0.378755 val accuracy: 0.371000
# lr 1.000000e-06 reg 2.400000e+05 train accuracy: 0.365939 val accuracy: 0.375000
# lr 1.000000e-06 reg 2.425000e+05 train accuracy: 0.366204 val accuracy: 0.369000
# lr 1.000000e-06 reg 2.450000e+05 train accuracy: 0.361122 val accuracy: 0.379000
# lr 1.000000e-06 reg 2.475000e+05 train accuracy: 0.350796 val accuracy: 0.338000
# lr 1.000000e-06 reg 2.500000e+05 train accuracy: 0.365857 val accuracy: 0.352000
# lr 1.000000e-06 reg 2.525000e+05 train accuracy: 0.384878 val accuracy: 0.392000
# lr 1.000000e-06 reg 2.550000e+05 train accuracy: 0.354367 val accuracy: 0.346000
# lr 1.000000e-06 reg 2.575000e+05 train accuracy: 0.358265 val accuracy: 0.353000
# lr 1.000000e-06 reg 2.600000e+05 train accuracy: 0.376735 val accuracy: 0.386000
# lr 1.000000e-06 reg 2.625000e+05 train accuracy: 0.350469 val accuracy: 0.363000
# lr 1.000000e-06 reg 2.650000e+05 train accuracy: 0.356143 val accuracy: 0.361000
# lr 1.000000e-06 reg 2.675000e+05 train accuracy: 0.361102 val accuracy: 0.357000
# lr 1.000000e-06 reg 2.700000e+05 train accuracy: 0.376857 val accuracy: 0.398000
# lr 1.000000e-06 reg 2.725000e+05 train accuracy: 0.364000 val accuracy: 0.363000
# lr 1.000000e-06 reg 2.750000e+05 train accuracy: 0.371510 val accuracy: 0.382000
# lr 1.000000e-06 reg 2.775000e+05 train accuracy: 0.362082 val accuracy: 0.353000
# lr 1.000000e-06 reg 2.800000e+05 train accuracy: 0.356429 val accuracy: 0.342000
# lr 1.000000e-06 reg 2.825000e+05 train accuracy: 0.359837 val accuracy: 0.379000
# lr 1.000000e-06 reg 2.850000e+05 train accuracy: 0.364816 val accuracy: 0.351000
# lr 1.000000e-06 reg 2.875000e+05 train accuracy: 0.357102 val accuracy: 0.376000
# lr 1.000000e-06 reg 2.900000e+05 train accuracy: 0.362531 val accuracy: 0.349000
# lr 1.000000e-06 reg 2.925000e+05 train accuracy: 0.363347 val accuracy: 0.374000
# lr 1.000000e-06 reg 2.950000e+05 train accuracy: 0.363367 val accuracy: 0.371000
# lr 1.000000e-06 reg 2.975000e+05 train accuracy: 0.374265 val accuracy: 0.358000
# lr 1.000000e-06 reg 3.000000e+05 train accuracy: 0.365082 val accuracy: 0.355000
# lr 6.000000e-06 reg 7.000000e+04 train accuracy: 0.329449 val accuracy: 0.341000
# lr 6.000000e-06 reg 7.250000e+04 train accuracy: 0.346061 val accuracy: 0.345000
# lr 6.000000e-06 reg 7.500000e+04 train accuracy: 0.352878 val accuracy: 0.337000
# lr 6.000000e-06 reg 7.750000e+04 train accuracy: 0.334429 val accuracy: 0.311000
# lr 6.000000e-06 reg 8.000000e+04 train accuracy: 0.323204 val accuracy: 0.308000
# lr 6.000000e-06 reg 8.250000e+04 train accuracy: 0.333020 val accuracy: 0.344000
# lr 6.000000e-06 reg 8.500000e+04 train accuracy: 0.325490 val accuracy: 0.317000
# lr 6.000000e-06 reg 8.750000e+04 train accuracy: 0.314531 val accuracy: 0.318000
# lr 6.000000e-06 reg 9.000000e+04 train accuracy: 0.310980 val accuracy: 0.289000
# lr 6.000000e-06 reg 9.250000e+04 train accuracy: 0.292571 val accuracy: 0.264000
# lr 6.000000e-06 reg 9.500000e+04 train accuracy: 0.308102 val accuracy: 0.314000
# lr 6.000000e-06 reg 9.750000e+04 train accuracy: 0.290224 val accuracy: 0.323000
# lr 6.000000e-06 reg 1.000000e+05 train accuracy: 0.285857 val accuracy: 0.293000
# lr 6.000000e-06 reg 1.025000e+05 train accuracy: 0.306102 val accuracy: 0.270000
# lr 6.000000e-06 reg 1.050000e+05 train accuracy: 0.311571 val accuracy: 0.325000
# lr 6.000000e-06 reg 1.075000e+05 train accuracy: 0.297102 val accuracy: 0.322000
# lr 6.000000e-06 reg 1.100000e+05 train accuracy: 0.274939 val accuracy: 0.255000
# lr 6.000000e-06 reg 1.125000e+05 train accuracy: 0.305388 val accuracy: 0.316000
# lr 6.000000e-06 reg 1.150000e+05 train accuracy: 0.299000 val accuracy: 0.303000
# lr 6.000000e-06 reg 1.175000e+05 train accuracy: 0.286878 val accuracy: 0.290000
# lr 6.000000e-06 reg 1.200000e+05 train accuracy: 0.269878 val accuracy: 0.247000
# lr 6.000000e-06 reg 1.225000e+05 train accuracy: 0.276735 val accuracy: 0.308000
# lr 6.000000e-06 reg 1.250000e+05 train accuracy: 0.291347 val accuracy: 0.294000
# lr 6.000000e-06 reg 1.275000e+05 train accuracy: 0.251490 val accuracy: 0.245000
# lr 6.000000e-06 reg 1.300000e+05 train accuracy: 0.250143 val accuracy: 0.279000
# lr 6.000000e-06 reg 1.325000e+05 train accuracy: 0.265490 val accuracy: 0.274000
# lr 6.000000e-06 reg 1.350000e+05 train accuracy: 0.257102 val accuracy: 0.258000
# lr 6.000000e-06 reg 1.375000e+05 train accuracy: 0.218878 val accuracy: 0.189000
# lr 6.000000e-06 reg 1.400000e+05 train accuracy: 0.231122 val accuracy: 0.256000
# lr 6.000000e-06 reg 1.425000e+05 train accuracy: 0.245163 val accuracy: 0.270000
# lr 6.000000e-06 reg 1.450000e+05 train accuracy: 0.239694 val accuracy: 0.248000
# lr 6.000000e-06 reg 1.475000e+05 train accuracy: 0.248796 val accuracy: 0.243000
# lr 6.000000e-06 reg 1.500000e+05 train accuracy: 0.204327 val accuracy: 0.198000
# lr 6.000000e-06 reg 1.525000e+05 train accuracy: 0.224551 val accuracy: 0.200000
# lr 6.000000e-06 reg 1.550000e+05 train accuracy: 0.219102 val accuracy: 0.228000
# lr 6.000000e-06 reg 1.575000e+05 train accuracy: 0.188755 val accuracy: 0.176000
# lr 6.000000e-06 reg 1.600000e+05 train accuracy: 0.185163 val accuracy: 0.191000
# lr 6.000000e-06 reg 1.625000e+05 train accuracy: 0.170714 val accuracy: 0.160000
# lr 6.000000e-06 reg 1.650000e+05 train accuracy: 0.083653 val accuracy: 0.077000
# lr 6.000000e-06 reg 1.675000e+05 train accuracy: 0.088306 val accuracy: 0.077000
# lr 6.000000e-06 reg 1.700000e+05 train accuracy: 0.097898 val accuracy: 0.096000
# lr 6.000000e-06 reg 1.725000e+05 train accuracy: 0.102694 val accuracy: 0.111000
# lr 6.000000e-06 reg 1.750000e+05 train accuracy: 0.108408 val accuracy: 0.110000
# lr 6.000000e-06 reg 1.775000e+05 train accuracy: 0.095061 val accuracy: 0.100000
# lr 6.000000e-06 reg 1.800000e+05 train accuracy: 0.113878 val accuracy: 0.122000
# lr 6.000000e-06 reg 1.825000e+05 train accuracy: 0.090143 val accuracy: 0.078000
# lr 6.000000e-06 reg 1.850000e+05 train accuracy: 0.081204 val accuracy: 0.068000
# lr 6.000000e-06 reg 1.875000e+05 train accuracy: 0.116286 val accuracy: 0.125000
# lr 6.000000e-06 reg 1.900000e+05 train accuracy: 0.095184 val accuracy: 0.084000
# lr 6.000000e-06 reg 1.925000e+05 train accuracy: 0.097571 val accuracy: 0.109000
# lr 6.000000e-06 reg 1.950000e+05 train accuracy: 0.106939 val accuracy: 0.119000
# lr 6.000000e-06 reg 1.975000e+05 train accuracy: 0.087082 val accuracy: 0.084000
# lr 6.000000e-06 reg 2.000000e+05 train accuracy: 0.089592 val accuracy: 0.098000
# lr 6.000000e-06 reg 2.025000e+05 train accuracy: 0.107041 val accuracy: 0.106000
# lr 6.000000e-06 reg 2.050000e+05 train accuracy: 0.096796 val accuracy: 0.098000
# lr 6.000000e-06 reg 2.075000e+05 train accuracy: 0.088265 val accuracy: 0.089000
# lr 6.000000e-06 reg 2.100000e+05 train accuracy: 0.097980 val accuracy: 0.091000
# lr 6.000000e-06 reg 2.125000e+05 train accuracy: 0.105796 val accuracy: 0.105000
# lr 6.000000e-06 reg 2.150000e+05 train accuracy: 0.099224 val accuracy: 0.113000
# lr 6.000000e-06 reg 2.175000e+05 train accuracy: 0.100061 val accuracy: 0.087000
# lr 6.000000e-06 reg 2.200000e+05 train accuracy: 0.093714 val accuracy: 0.098000
# lr 6.000000e-06 reg 2.225000e+05 train accuracy: 0.103694 val accuracy: 0.113000
# lr 6.000000e-06 reg 2.250000e+05 train accuracy: 0.090286 val accuracy: 0.084000
# lr 6.000000e-06 reg 2.275000e+05 train accuracy: 0.105306 val accuracy: 0.098000
# lr 6.000000e-06 reg 2.300000e+05 train accuracy: 0.104531 val accuracy: 0.101000
# lr 6.000000e-06 reg 2.325000e+05 train accuracy: 0.078776 val accuracy: 0.078000
# lr 6.000000e-06 reg 2.350000e+05 train accuracy: 0.108102 val accuracy: 0.112000
# lr 6.000000e-06 reg 2.375000e+05 train accuracy: 0.122020 val accuracy: 0.126000
# lr 6.000000e-06 reg 2.400000e+05 train accuracy: 0.104224 val accuracy: 0.103000
# lr 6.000000e-06 reg 2.425000e+05 train accuracy: 0.104265 val accuracy: 0.107000
# lr 6.000000e-06 reg 2.450000e+05 train accuracy: 0.101878 val accuracy: 0.070000
# lr 6.000000e-06 reg 2.475000e+05 train accuracy: 0.077122 val accuracy: 0.062000
# lr 6.000000e-06 reg 2.500000e+05 train accuracy: 0.104878 val accuracy: 0.095000
# lr 6.000000e-06 reg 2.525000e+05 train accuracy: 0.103735 val accuracy: 0.098000
# lr 6.000000e-06 reg 2.550000e+05 train accuracy: 0.100245 val accuracy: 0.091000
# lr 6.000000e-06 reg 2.575000e+05 train accuracy: 0.094265 val accuracy: 0.093000
# lr 6.000000e-06 reg 2.600000e+05 train accuracy: 0.111796 val accuracy: 0.119000
# lr 6.000000e-06 reg 2.625000e+05 train accuracy: 0.090612 val accuracy: 0.086000
# lr 6.000000e-06 reg 2.650000e+05 train accuracy: 0.110000 val accuracy: 0.137000
# lr 6.000000e-06 reg 2.675000e+05 train accuracy: 0.107918 val accuracy: 0.103000
# lr 6.000000e-06 reg 2.700000e+05 train accuracy: 0.097592 val accuracy: 0.097000
# lr 6.000000e-06 reg 2.725000e+05 train accuracy: 0.090959 val accuracy: 0.088000
# lr 6.000000e-06 reg 2.750000e+05 train accuracy: 0.112429 val accuracy: 0.135000
# lr 6.000000e-06 reg 2.775000e+05 train accuracy: 0.107245 val accuracy: 0.096000
# lr 6.000000e-06 reg 2.800000e+05 train accuracy: 0.092408 val accuracy: 0.081000
# lr 6.000000e-06 reg 2.825000e+05 train accuracy: 0.107184 val accuracy: 0.105000
# lr 6.000000e-06 reg 2.850000e+05 train accuracy: 0.089571 val accuracy: 0.101000
# lr 6.000000e-06 reg 2.875000e+05 train accuracy: 0.121286 val accuracy: 0.122000
# lr 6.000000e-06 reg 2.900000e+05 train accuracy: 0.105020 val accuracy: 0.108000
# lr 6.000000e-06 reg 2.925000e+05 train accuracy: 0.107612 val accuracy: 0.113000
# lr 6.000000e-06 reg 2.950000e+05 train accuracy: 0.085694 val accuracy: 0.093000
# lr 6.000000e-06 reg 2.975000e+05 train accuracy: 0.079510 val accuracy: 0.076000
# lr 6.000000e-06 reg 3.000000e+05 train accuracy: 0.095735 val accuracy: 0.084000
# lr 6.000000e-06 reg 3.025000e+05 train accuracy: 0.110673 val accuracy: 0.107000
# lr 6.000000e-06 reg 3.050000e+05 train accuracy: 0.080592 val accuracy: 0.089000
# lr 6.000000e-06 reg 3.075000e+05 train accuracy: 0.105224 val accuracy: 0.104000
# lr 6.000000e-06 reg 3.100000e+05 train accuracy: 0.100143 val accuracy: 0.096000
# lr 6.000000e-06 reg 3.125000e+05 train accuracy: 0.090510 val accuracy: 0.092000
# lr 6.000000e-06 reg 3.150000e+05 train accuracy: 0.123102 val accuracy: 0.127000
# lr 6.000000e-06 reg 3.175000e+05 train accuracy: 0.101673 val accuracy: 0.094000
# lr 6.000000e-06 reg 3.200000e+05 train accuracy: 0.118898 val accuracy: 0.110000
# lr 6.000000e-06 reg 3.225000e+05 train accuracy: 0.101449 val accuracy: 0.094000
# lr 6.000000e-06 reg 3.250000e+05 train accuracy: 0.084204 val accuracy: 0.088000
# lr 6.000000e-06 reg 3.275000e+05 train accuracy: 0.105163 val accuracy: 0.097000
# lr 6.000000e-06 reg 3.300000e+05 train accuracy: 0.103837 val accuracy: 0.112000
# lr 6.000000e-06 reg 3.325000e+05 train accuracy: 0.092857 val accuracy: 0.076000
# lr 6.000000e-06 reg 3.350000e+05 train accuracy: 0.078347 val accuracy: 0.063000
# lr 6.000000e-06 reg 3.375000e+05 train accuracy: 0.117122 val accuracy: 0.112000
# lr 6.000000e-06 reg 3.400000e+05 train accuracy: 0.118980 val accuracy: 0.098000
# lr 6.000000e-06 reg 3.425000e+05 train accuracy: 0.099939 val accuracy: 0.090000
# lr 6.000000e-06 reg 3.450000e+05 train accuracy: 0.125837 val accuracy: 0.111000
# lr 6.000000e-06 reg 3.475000e+05 train accuracy: 0.095204 val accuracy: 0.089000
# lr 6.000000e-06 reg 3.500000e+05 train accuracy: 0.091796 val accuracy: 0.094000
# lr 6.000000e-06 reg 3.525000e+05 train accuracy: 0.087408 val accuracy: 0.093000
# lr 6.000000e-06 reg 3.550000e+05 train accuracy: 0.118571 val accuracy: 0.138000
# lr 6.000000e-06 reg 3.575000e+05 train accuracy: 0.072367 val accuracy: 0.079000
# lr 6.000000e-06 reg 3.600000e+05 train accuracy: 0.095735 val accuracy: 0.084000
# lr 6.000000e-06 reg 3.625000e+05 train accuracy: 0.121143 val accuracy: 0.130000
# lr 6.000000e-06 reg 3.650000e+05 train accuracy: 0.112265 val accuracy: 0.097000
# lr 6.000000e-06 reg 3.675000e+05 train accuracy: 0.089837 val accuracy: 0.083000
# lr 6.000000e-06 reg 3.700000e+05 train accuracy: 0.085755 val accuracy: 0.094000
# lr 6.000000e-06 reg 3.725000e+05 train accuracy: 0.088653 val accuracy: 0.087000
# lr 6.000000e-06 reg 3.750000e+05 train accuracy: 0.093918 val accuracy: 0.103000
# lr 6.000000e-06 reg 3.775000e+05 train accuracy: 0.074633 val accuracy: 0.067000
# lr 6.000000e-06 reg 3.800000e+05 train accuracy: 0.117694 val accuracy: 0.108000
# lr 6.000000e-06 reg 3.825000e+05 train accuracy: 0.103204 val accuracy: 0.095000
# lr 6.000000e-06 reg 3.850000e+05 train accuracy: 0.087367 val accuracy: 0.083000
# lr 6.000000e-06 reg 3.875000e+05 train accuracy: 0.088939 val accuracy: 0.088000
# lr 6.000000e-06 reg 3.900000e+05 train accuracy: 0.098653 val accuracy: 0.120000
# lr 6.000000e-06 reg 3.925000e+05 train accuracy: 0.098163 val accuracy: 0.105000
# lr 6.000000e-06 reg 3.950000e+05 train accuracy: 0.098980 val accuracy: 0.107000
# lr 6.000000e-06 reg 3.975000e+05 train accuracy: 0.095102 val accuracy: 0.101000
# lr 6.000000e-06 reg 4.000000e+05 train accuracy: 0.096224 val accuracy: 0.094000
# lr 6.000000e-06 reg 4.025000e+05 train accuracy: 0.117327 val accuracy: 0.109000
# lr 6.000000e-06 reg 4.050000e+05 train accuracy: 0.124408 val accuracy: 0.127000
# lr 6.000000e-06 reg 4.075000e+05 train accuracy: 0.112163 val accuracy: 0.103000
# lr 6.000000e-06 reg 4.100000e+05 train accuracy: 0.102000 val accuracy: 0.090000
# lr 6.000000e-06 reg 4.125000e+05 train accuracy: 0.090714 val accuracy: 0.104000
# lr 6.000000e-06 reg 4.150000e+05 train accuracy: 0.099959 val accuracy: 0.096000
# lr 6.000000e-06 reg 4.175000e+05 train accuracy: 0.108286 val accuracy: 0.123000
# lr 6.000000e-06 reg 4.200000e+05 train accuracy: 0.089408 val accuracy: 0.107000
# lr 6.000000e-06 reg 4.225000e+05 train accuracy: 0.091000 val accuracy: 0.083000
# lr 6.000000e-06 reg 4.250000e+05 train accuracy: 0.114184 val accuracy: 0.131000
# lr 6.000000e-06 reg 4.275000e+05 train accuracy: 0.093939 val accuracy: 0.102000
# lr 6.000000e-06 reg 4.300000e+05 train accuracy: 0.105898 val accuracy: 0.112000
# lr 6.000000e-06 reg 4.325000e+05 train accuracy: 0.086755 val accuracy: 0.065000
# lr 6.000000e-06 reg 4.350000e+05 train accuracy: 0.130551 val accuracy: 0.114000
# lr 6.000000e-06 reg 4.375000e+05 train accuracy: 0.108633 val accuracy: 0.117000
# lr 6.000000e-06 reg 4.400000e+05 train accuracy: 0.096245 val accuracy: 0.087000
# lr 6.000000e-06 reg 4.425000e+05 train accuracy: 0.106714 val accuracy: 0.110000
# lr 6.000000e-06 reg 4.450000e+05 train accuracy: 0.103980 val accuracy: 0.098000
# lr 6.000000e-06 reg 4.475000e+05 train accuracy: 0.133020 val accuracy: 0.125000
# lr 6.000000e-06 reg 4.500000e+05 train accuracy: 0.094122 val accuracy: 0.086000
# lr 6.000000e-06 reg 4.525000e+05 train accuracy: 0.108653 val accuracy: 0.109000
# lr 6.000000e-06 reg 4.550000e+05 train accuracy: 0.128878 val accuracy: 0.113000
# lr 6.000000e-06 reg 4.575000e+05 train accuracy: 0.072020 val accuracy: 0.064000
# lr 6.000000e-06 reg 4.600000e+05 train accuracy: 0.095878 val accuracy: 0.098000
# lr 6.000000e-06 reg 4.625000e+05 train accuracy: 0.100327 val accuracy: 0.095000
# lr 6.000000e-06 reg 4.650000e+05 train accuracy: 0.095286 val accuracy: 0.113000
# lr 6.000000e-06 reg 4.675000e+05 train accuracy: 0.109673 val accuracy: 0.119000
# lr 6.000000e-06 reg 4.700000e+05 train accuracy: 0.107816 val accuracy: 0.092000
# lr 6.000000e-06 reg 4.725000e+05 train accuracy: 0.108041 val accuracy: 0.103000
# lr 6.000000e-06 reg 4.750000e+05 train accuracy: 0.106184 val accuracy: 0.102000
# lr 6.000000e-06 reg 4.775000e+05 train accuracy: 0.089163 val accuracy: 0.080000
# lr 6.000000e-06 reg 4.800000e+05 train accuracy: 0.093959 val accuracy: 0.112000
# lr 8.500000e-06 reg 7.750000e+04 train accuracy: 0.294755 val accuracy: 0.277000
# lr 8.500000e-06 reg 8.000000e+04 train accuracy: 0.309857 val accuracy: 0.317000
# lr 8.500000e-06 reg 8.250000e+04 train accuracy: 0.267959 val accuracy: 0.252000
# lr 8.500000e-06 reg 8.500000e+04 train accuracy: 0.274571 val accuracy: 0.273000
# lr 8.500000e-06 reg 8.750000e+04 train accuracy: 0.274755 val accuracy: 0.285000
# lr 8.500000e-06 reg 9.000000e+04 train accuracy: 0.275694 val accuracy: 0.285000
# lr 8.500000e-06 reg 9.250000e+04 train accuracy: 0.248286 val accuracy: 0.239000
# lr 8.500000e-06 reg 9.500000e+04 train accuracy: 0.269122 val accuracy: 0.262000
# lr 8.500000e-06 reg 9.750000e+04 train accuracy: 0.250388 val accuracy: 0.275000
# lr 8.500000e-06 reg 1.000000e+05 train accuracy: 0.261592 val accuracy: 0.285000
# lr 8.500000e-06 reg 1.025000e+05 train accuracy: 0.251327 val accuracy: 0.236000
# lr 8.500000e-06 reg 1.050000e+05 train accuracy: 0.204612 val accuracy: 0.203000
# lr 8.500000e-06 reg 1.075000e+05 train accuracy: 0.243429 val accuracy: 0.262000
# lr 8.500000e-06 reg 1.100000e+05 train accuracy: 0.208694 val accuracy: 0.213000
# lr 8.500000e-06 reg 1.125000e+05 train accuracy: 0.189265 val accuracy: 0.188000
# lr 8.500000e-06 reg 1.150000e+05 train accuracy: 0.153980 val accuracy: 0.149000
# lr 8.500000e-06 reg 1.175000e+05 train accuracy: 0.095714 val accuracy: 0.100000
# lr 8.500000e-06 reg 1.200000e+05 train accuracy: 0.094939 val accuracy: 0.105000
# lr 8.500000e-06 reg 1.225000e+05 train accuracy: 0.096898 val accuracy: 0.103000
# lr 8.500000e-06 reg 1.250000e+05 train accuracy: 0.092367 val accuracy: 0.099000
# lr 8.500000e-06 reg 1.275000e+05 train accuracy: 0.103837 val accuracy: 0.111000
# lr 8.500000e-06 reg 1.300000e+05 train accuracy: 0.091082 val accuracy: 0.096000
# lr 8.500000e-06 reg 1.325000e+05 train accuracy: 0.121388 val accuracy: 0.114000
# lr 8.500000e-06 reg 1.350000e+05 train accuracy: 0.095735 val accuracy: 0.104000
# lr 8.500000e-06 reg 1.375000e+05 train accuracy: 0.084510 val accuracy: 0.091000
# lr 8.500000e-06 reg 1.400000e+05 train accuracy: 0.098837 val accuracy: 0.112000
# lr 8.500000e-06 reg 1.425000e+05 train accuracy: 0.104980 val accuracy: 0.103000
# lr 8.500000e-06 reg 1.450000e+05 train accuracy: 0.091714 val accuracy: 0.089000
# lr 8.500000e-06 reg 1.475000e+05 train accuracy: 0.095490 val accuracy: 0.090000
# lr 8.500000e-06 reg 1.500000e+05 train accuracy: 0.108102 val accuracy: 0.098000
# lr 8.500000e-06 reg 1.525000e+05 train accuracy: 0.122551 val accuracy: 0.116000
# lr 8.500000e-06 reg 1.550000e+05 train accuracy: 0.083653 val accuracy: 0.071000
# lr 8.500000e-06 reg 1.575000e+05 train accuracy: 0.082633 val accuracy: 0.080000
# lr 8.500000e-06 reg 1.600000e+05 train accuracy: 0.084184 val accuracy: 0.095000
# lr 8.500000e-06 reg 1.625000e+05 train accuracy: 0.110020 val accuracy: 0.104000
# lr 8.500000e-06 reg 1.650000e+05 train accuracy: 0.097204 val accuracy: 0.103000
# lr 8.500000e-06 reg 1.675000e+05 train accuracy: 0.100918 val accuracy: 0.101000
# lr 8.500000e-06 reg 1.700000e+05 train accuracy: 0.111857 val accuracy: 0.110000
# lr 8.500000e-06 reg 1.725000e+05 train accuracy: 0.090163 val accuracy: 0.096000
# lr 8.500000e-06 reg 1.750000e+05 train accuracy: 0.098735 val accuracy: 0.110000
# lr 8.500000e-06 reg 1.775000e+05 train accuracy: 0.094286 val accuracy: 0.097000
# lr 8.500000e-06 reg 1.800000e+05 train accuracy: 0.095122 val accuracy: 0.075000
# lr 8.500000e-06 reg 1.825000e+05 train accuracy: 0.093327 val accuracy: 0.083000
# lr 8.500000e-06 reg 1.850000e+05 train accuracy: 0.103857 val accuracy: 0.110000
# lr 8.500000e-06 reg 1.875000e+05 train accuracy: 0.085980 val accuracy: 0.095000
# lr 8.500000e-06 reg 1.900000e+05 train accuracy: 0.096184 val accuracy: 0.090000
# lr 8.500000e-06 reg 1.925000e+05 train accuracy: 0.123449 val accuracy: 0.128000
# lr 8.500000e-06 reg 1.950000e+05 train accuracy: 0.120714 val accuracy: 0.125000
# lr 8.500000e-06 reg 1.975000e+05 train accuracy: 0.096612 val accuracy: 0.097000
# lr 8.500000e-06 reg 2.000000e+05 train accuracy: 0.093367 val accuracy: 0.093000
# lr 8.500000e-06 reg 2.025000e+05 train accuracy: 0.091347 val accuracy: 0.077000
# lr 8.500000e-06 reg 2.050000e+05 train accuracy: 0.080265 val accuracy: 0.079000
# lr 8.500000e-06 reg 2.075000e+05 train accuracy: 0.087306 val accuracy: 0.093000
# lr 8.500000e-06 reg 2.100000e+05 train accuracy: 0.112327 val accuracy: 0.123000
# lr 8.500000e-06 reg 2.125000e+05 train accuracy: 0.112776 val accuracy: 0.106000
# lr 8.500000e-06 reg 2.150000e+05 train accuracy: 0.088490 val accuracy: 0.098000
# lr 8.500000e-06 reg 2.175000e+05 train accuracy: 0.095122 val accuracy: 0.089000
# lr 8.500000e-06 reg 2.200000e+05 train accuracy: 0.119286 val accuracy: 0.129000
# lr 8.500000e-06 reg 2.225000e+05 train accuracy: 0.121327 val accuracy: 0.125000
# lr 8.500000e-06 reg 2.250000e+05 train accuracy: 0.093449 val accuracy: 0.094000
# lr 8.500000e-06 reg 2.275000e+05 train accuracy: 0.116857 val accuracy: 0.126000
# lr 8.500000e-06 reg 2.300000e+05 train accuracy: 0.103041 val accuracy: 0.107000
# lr 8.500000e-06 reg 2.325000e+05 train accuracy: 0.077184 val accuracy: 0.076000
# lr 8.500000e-06 reg 2.350000e+05 train accuracy: 0.098653 val accuracy: 0.087000
# lr 8.500000e-06 reg 2.375000e+05 train accuracy: 0.082306 val accuracy: 0.082000
# lr 8.500000e-06 reg 2.400000e+05 train accuracy: 0.109531 val accuracy: 0.112000
# lr 8.500000e-06 reg 2.425000e+05 train accuracy: 0.096265 val accuracy: 0.093000
# lr 8.500000e-06 reg 2.450000e+05 train accuracy: 0.086265 val accuracy: 0.095000
# lr 8.500000e-06 reg 2.475000e+05 train accuracy: 0.089510 val accuracy: 0.099000
# lr 8.500000e-06 reg 2.500000e+05 train accuracy: 0.127367 val accuracy: 0.132000
# lr 8.500000e-06 reg 2.525000e+05 train accuracy: 0.107388 val accuracy: 0.127000
# lr 8.500000e-06 reg 2.550000e+05 train accuracy: 0.107408 val accuracy: 0.108000
# lr 8.500000e-06 reg 2.575000e+05 train accuracy: 0.100878 val accuracy: 0.092000
# lr 8.500000e-06 reg 2.600000e+05 train accuracy: 0.103367 val accuracy: 0.105000
# lr 8.500000e-06 reg 2.625000e+05 train accuracy: 0.103816 val accuracy: 0.123000
# lr 8.500000e-06 reg 2.650000e+05 train accuracy: 0.123469 val accuracy: 0.142000
# lr 8.500000e-06 reg 2.675000e+05 train accuracy: 0.101592 val accuracy: 0.088000
# lr 8.500000e-06 reg 2.700000e+05 train accuracy: 0.142224 val accuracy: 0.127000
# lr 8.500000e-06 reg 2.725000e+05 train accuracy: 0.100061 val accuracy: 0.104000
# lr 8.500000e-06 reg 2.750000e+05 train accuracy: 0.089878 val accuracy: 0.091000
# lr 8.500000e-06 reg 2.775000e+05 train accuracy: 0.100714 val accuracy: 0.100000
# lr 8.500000e-06 reg 2.800000e+05 train accuracy: 0.075510 val accuracy: 0.075000
# lr 8.500000e-06 reg 2.825000e+05 train accuracy: 0.071429 val accuracy: 0.083000
# lr 8.500000e-06 reg 2.850000e+05 train accuracy: 0.096265 val accuracy: 0.098000
# lr 8.500000e-06 reg 2.875000e+05 train accuracy: 0.105755 val accuracy: 0.119000
# lr 8.500000e-06 reg 2.900000e+05 train accuracy: 0.102673 val accuracy: 0.105000
# lr 8.500000e-06 reg 2.925000e+05 train accuracy: 0.080918 val accuracy: 0.074000
# lr 8.500000e-06 reg 2.950000e+05 train accuracy: 0.115673 val accuracy: 0.121000
# lr 8.500000e-06 reg 2.975000e+05 train accuracy: 0.121163 val accuracy: 0.117000
# lr 8.500000e-06 reg 3.000000e+05 train accuracy: 0.115510 val accuracy: 0.129000
# lr 8.500000e-06 reg 3.025000e+05 train accuracy: 0.093510 val accuracy: 0.084000
# lr 8.500000e-06 reg 3.050000e+05 train accuracy: 0.097286 val accuracy: 0.091000
# lr 8.500000e-06 reg 3.075000e+05 train accuracy: 0.084469 val accuracy: 0.085000
# lr 8.500000e-06 reg 3.100000e+05 train accuracy: 0.117286 val accuracy: 0.130000
# lr 8.500000e-06 reg 3.125000e+05 train accuracy: 0.118755 val accuracy: 0.123000
# lr 8.500000e-06 reg 3.150000e+05 train accuracy: 0.104490 val accuracy: 0.100000
# lr 8.500000e-06 reg 3.175000e+05 train accuracy: 0.100224 val accuracy: 0.093000
# lr 8.500000e-06 reg 3.200000e+05 train accuracy: 0.101918 val accuracy: 0.102000
# lr 8.500000e-06 reg 3.225000e+05 train accuracy: 0.093959 val accuracy: 0.092000
# lr 8.500000e-06 reg 3.250000e+05 train accuracy: 0.108510 val accuracy: 0.112000
# lr 8.500000e-06 reg 3.275000e+05 train accuracy: 0.082898 val accuracy: 0.078000
# lr 8.500000e-06 reg 3.300000e+05 train accuracy: 0.105449 val accuracy: 0.118000
# lr 8.500000e-06 reg 3.325000e+05 train accuracy: 0.077592 val accuracy: 0.079000
# lr 8.500000e-06 reg 3.350000e+05 train accuracy: 0.080000 val accuracy: 0.084000
# lr 8.500000e-06 reg 3.375000e+05 train accuracy: 0.087633 val accuracy: 0.084000
# lr 8.500000e-06 reg 3.400000e+05 train accuracy: 0.121469 val accuracy: 0.130000
# lr 8.500000e-06 reg 3.425000e+05 train accuracy: 0.080592 val accuracy: 0.065000
# lr 8.500000e-06 reg 3.450000e+05 train accuracy: 0.098306 val accuracy: 0.094000
# lr 8.500000e-06 reg 3.475000e+05 train accuracy: 0.091816 val accuracy: 0.096000
# lr 8.500000e-06 reg 3.500000e+05 train accuracy: 0.092102 val accuracy: 0.109000
# lr 8.500000e-06 reg 3.525000e+05 train accuracy: 0.120551 val accuracy: 0.124000
# lr 8.500000e-06 reg 3.550000e+05 train accuracy: 0.104755 val accuracy: 0.098000
# lr 8.500000e-06 reg 3.575000e+05 train accuracy: 0.093143 val accuracy: 0.089000
# lr 8.500000e-06 reg 3.600000e+05 train accuracy: 0.113939 val accuracy: 0.107000
# lr 8.500000e-06 reg 3.625000e+05 train accuracy: 0.101939 val accuracy: 0.108000
# lr 8.500000e-06 reg 3.650000e+05 train accuracy: 0.135959 val accuracy: 0.127000
# lr 8.500000e-06 reg 3.675000e+05 train accuracy: 0.091224 val accuracy: 0.082000
# lr 8.500000e-06 reg 3.700000e+05 train accuracy: 0.103184 val accuracy: 0.116000
# lr 8.500000e-06 reg 3.725000e+05 train accuracy: 0.108204 val accuracy: 0.119000
# lr 8.500000e-06 reg 3.750000e+05 train accuracy: 0.113347 val accuracy: 0.129000
# lr 8.500000e-06 reg 3.775000e+05 train accuracy: 0.116204 val accuracy: 0.105000
# lr 8.500000e-06 reg 3.800000e+05 train accuracy: 0.098571 val accuracy: 0.101000
# lr 8.500000e-06 reg 3.825000e+05 train accuracy: 0.105796 val accuracy: 0.096000
# lr 8.500000e-06 reg 3.850000e+05 train accuracy: 0.091796 val accuracy: 0.085000
# lr 8.500000e-06 reg 3.875000e+05 train accuracy: 0.092245 val accuracy: 0.083000
# lr 8.500000e-06 reg 3.900000e+05 train accuracy: 0.079571 val accuracy: 0.083000
# lr 8.500000e-06 reg 3.925000e+05 train accuracy: 0.079878 val accuracy: 0.079000
# lr 8.500000e-06 reg 3.950000e+05 train accuracy: 0.084796 val accuracy: 0.088000
# lr 8.500000e-06 reg 3.975000e+05 train accuracy: 0.084918 val accuracy: 0.077000
# lr 8.500000e-06 reg 4.000000e+05 train accuracy: 0.112184 val accuracy: 0.110000
# lr 8.500000e-06 reg 4.025000e+05 train accuracy: 0.108837 val accuracy: 0.100000
# lr 8.500000e-06 reg 4.050000e+05 train accuracy: 0.091388 val accuracy: 0.084000
# lr 8.500000e-06 reg 4.925000e+05 train accuracy: 0.102571 val accuracy: 0.099000
# lr 8.500000e-06 reg 4.950000e+05 train accuracy: 0.100102 val accuracy: 0.098000
# lr 8.500000e-06 reg 4.975000e+05 train accuracy: 0.082755 val accuracy: 0.073000
# best validation accuracy achieved: 0.427000

# %%
## Evaluate your trained SVM on the test set: you should be able to get at least 0.40
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.397

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$ No. Generally, they are different class.
# In plane class, some samples have wings, this model classify samples to plane class. And, for truck class, some samples seem to like horse, and had lassified truck class.

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 155)
# (49000, 154)

# %%
from cs231n.classifiers.fc_net import TwoLayerNet
from cs231n.solver import Solver

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

best_val_acc = -1

data = {'X_train': X_train_feats, 'X_val': X_val_feats, 'y_train': y_train, 'y_val': y_val}

# learning_rates = np.arange(1e-6, 1e-5, 2.5e-6)
learning_rates = [1e-6, 1e-5, 1e-4, 5e-4, 1e-3, 5e-3, 1e-2, 5e-2, 1e-1]
regularization_strengths = [1e-1, 0, 1, 1e1, 1e2, 5e2, 1e3, 5e3, 1e4, 5e4, 1e5, 5e5, 1e6]


for lr in learning_rates:
    for rs in regularization_strengths:
        net = TwoLayerNet(input_dim, hidden_dim, num_classes, reg=rs)
        solver = Solver(net, data,
                        update_rule='sgd',
                        optim_config={
                            'learning_rate': lr,
                        },
                        lr_decay=0.95,
                        num_epochs=10, batch_size=100,
                        print_every=100, verbose=False) 
        solver.train()

        if solver.best_val_acc > best_val_acc:
            best_val_acc = solver.best_val_acc
            best_net = net

            print("lr: %f, reg: %f, val_accuracy: %f" %(lr, rs, best_val_acc))


# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# lr: 0.000001, reg: 0.100000, val_accuracy: 0.106000
# lr: 0.000001, reg: 0.000000, val_accuracy: 0.110000
# lr: 0.000001, reg: 100.000000, val_accuracy: 0.116000
# lr: 0.000001, reg: 5000.000000, val_accuracy: 0.119000
# lr: 0.000001, reg: 100000.000000, val_accuracy: 0.130000
# lr: 0.000010, reg: 0.100000, val_accuracy: 0.132000
# lr: 0.000010, reg: 100.000000, val_accuracy: 0.137000
# /content/drive/My Drive/CS231n/assignment1/cs231n/layers.py:210: RuntimeWarning: divide by zero encountered in log
#   loss = np.sum(-np.log(correct / np.sum(prob, axis=1))) / num_train
# /content/drive/My Drive/CS231n/assignment1/cs231n/classifiers/fc_net.py:134: RuntimeWarning: overflow encountered in double_scalars
#   loss += 0.5 * self.reg * np.sum(self.params['W1'] * self.params['W1'])
# /content/drive/My Drive/CS231n/assignment1/cs231n/classifiers/fc_net.py:133: RuntimeWarning: overflow encountered in double_scalars
#   loss += 0.5 * self.reg * np.sum(self.params['W2'] * self.params['W2'])
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /content/drive/My Drive/CS231n/assignment1/cs231n/layers.py:199: RuntimeWarning: overflow encountered in subtract
#   x = x - np.max(x, axis=1).reshape(-1, 1) # for numerical instability...
# /content/drive/My Drive/CS231n/assignment1/cs231n/layers.py:199: RuntimeWarning: invalid value encountered in subtract
#   x = x - np.max(x, axis=1).reshape(-1, 1) # for numerical instability...
# /content/drive/My Drive/CS231n/assignment1/cs231n/classifiers/fc_net.py:134: RuntimeWarning: overflow encountered in multiply
#   loss += 0.5 * self.reg * np.sum(self.params['W1'] * self.params['W1'])
# /content/drive/My Drive/CS231n/assignment1/cs231n/classifiers/fc_net.py:133: RuntimeWarning: overflow encountered in multiply
#   loss += 0.5 * self.reg * np.sum(self.params['W2'] * self.params['W2'])
# lr: 0.000500, reg: 0.100000, val_accuracy: 0.197000
# lr: 0.001000, reg: 0.100000, val_accuracy: 0.207000
# lr: 0.001000, reg: 0.000000, val_accuracy: 0.270000
# lr: 0.005000, reg: 0.100000, val_accuracy: 0.277000
# lr: 0.005000, reg: 0.000000, val_accuracy: 0.362000
# lr: 0.010000, reg: 0.000000, val_accuracy: 0.477000
# lr: 0.050000, reg: 0.000000, val_accuracy: 0.551000
# lr: 0.100000, reg: 0.000000, val_accuracy: 0.593000

# %%
data = {'X_train': X_train_feats, 'X_val': X_val_feats, 'y_train': y_train, 'y_val': y_val, 'X_test': X_test_feats, 'y_test': y_test}

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

y_test_pred = np.argmax(best_net.loss(data['X_test']), axis=1)
test_acc = (y_test_pred == data['y_test']).mean()
print(test_acc)
# Out:
# 0.577
